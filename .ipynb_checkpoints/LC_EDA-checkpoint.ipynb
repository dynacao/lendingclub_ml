# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
lc_df = pd.read_csv('../data/lc_cleaned.csv')

# %%
lc_df.sample(5)
# Out:
#           amount                    title  risk_score  debt_to_income_ratio  \
# 210966   15000.0       debt consolidation       749.0                0.1203
# 1948168  24000.0       debt consolidation       719.0                0.2904
# 569746    7000.0  credit card refinancing       679.0                0.0225
# 2715658  15000.0         home improvement       659.0                0.1855
# 547017   10075.0       debt consolidation       569.0                0.2568
#
#         state length_of_emp  policy_code  year  status     region  \
# 210966     CA           NaN          1.0  2015       1       West
# 1948168    OR       3 years          1.0  2016       1       West
# 569746     IL       9 years          1.0  2017       1    Midwest
# 2715658    VT      < 1 year          0.0  2012       0  Northeast
# 547017     OR       2 years          1.0  2017       1       West
#
#                    division
# 210966              Pacific
# 1948168             Pacific
# 569746   East North Central
# 2715658         New England
# 547017              Pacific

# %%
lc_df.status.value_counts()
# Out:
# 1    2260668
# 0    1048554
# Name: status, dtype: int64

# %%
lc_df.describe()
# Out:
#              amount    risk_score  debt_to_income_ratio   policy_code  \
# count  3.309222e+06  3.042280e+06          3.307511e+06  3.309222e+06
# mean   1.447392e+04  6.636889e+02          2.652142e+00  6.837843e-01
# std    1.060232e+04  1.159391e+02          2.873955e+02  4.656886e-01
# min    0.000000e+00  0.000000e+00         -1.000000e-02  0.000000e+00
# 25%    6.500000e+03  6.300000e+02          1.059000e-01  0.000000e+00
# 50%    1.200000e+04  6.840000e+02          1.770000e-01  1.000000e+00
# 75%    2.000000e+04  7.240000e+02          2.586000e-01  1.000000e+00
# max    1.400000e+06  9.750000e+02          5.000003e+05  2.000000e+00
#
#                year        status
# count  3.309222e+06  3.309222e+06
# mean   2.014765e+03  6.831418e-01
# std    2.579288e+00  4.652517e-01
# min    2.007000e+03  0.000000e+00
# 25%    2.012000e+03  0.000000e+00
# 50%    2.016000e+03  1.000000e+00
# 75%    2.017000e+03  1.000000e+00
# max    2.018000e+03  1.000000e+00

# %% [markdown]
# approval by year

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.lineplot(data = lc_df, x = 'year', y = 'status', estimator = 'mean', ci = 99)

# %% [markdown]
# use data from 2007 to 2012

# %%
lc_eo2012 = lc_df[lc_df['year']<=2012]

# %%
print(lc_eo2012.shape)
print('--'*30)
print(lc_eo2012.status.value_counts())
# Out:
# (851372, 11)
# ------------------------------------------------------------
# 0    755470
# 1     95902
# Name: status, dtype: int64

# %%
lc_eo2012 = lc_eo2012.sort_values(['year','state','length_of_emp'], ascending = [True, True, False]).\
            reset_index().drop(['index'], axis = 1)

# %%
lc_eo2012.head(5)
# Out:
#     amount       title  risk_score  debt_to_income_ratio state length_of_emp  \
# 0   5000.0    kcgyrl79       539.0                0.0000    AK      < 1 year
# 1    500.0      rbinak       526.0                0.2103    AK      < 1 year
# 2  25000.0      akav8r       693.0                0.4425    AK      < 1 year
# 3  21250.0      emorle       441.0                0.1305    AK      < 1 year
# 4   9000.0  yancyrandi       564.0                0.0358    AK      < 1 year
#
#    policy_code  year  status region division
# 0          0.0  2007       0   West  Pacific
# 1          0.0  2007       0   West  Pacific
# 2          0.0  2007       0   West  Pacific
# 3          0.0  2007       0   West  Pacific
# 4          0.0  2007       0   West  Pacific

# %%
sns.lineplot(data = lc_eo2012, x = 'year', y = 'status', estimator = 'mean', ci = 99)

# %% [markdown]
# credit score vs approval

# %%
sns.set(rc={'figure.figsize':(7, 4)})
sns.barplot(data = lc_eo2012, x = 'status', y = 'risk_score', ci = 99)

# %% [markdown]
# amount vs approval

# %%
sns.set(rc={'figure.figsize':(7, 4)})
sns.barplot(data = lc_eo2012, x = 'status', y = 'amount', ci = 99)

# %% [markdown]
# num of requests by credit score by approval

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.distplot(lc_eo2012[lc_eo2012['status'] == 1].risk_score, bins = 30, hist = True, rug = False)
sns.distplot(lc_eo2012[lc_eo2012['status'] == 0].risk_score, bins = 30, hist = True, rug = False)

# %% [markdown]
# debt-to-inc-ratio vs approval

# %%
sns.set(rc={'figure.figsize':(7, 4)})
sns.barplot(data = lc_eo2012, x = 'status', y = 'debt_to_income_ratio', ci = 99)

# %% [markdown]
# debt-to-income ratio by length of emp and approval

# %%
b = sns.FacetGrid(lc_eo2012, col = 'status', sharey = False, height = 5, aspect = 1.75)
b.map(sns.barplot, 'length_of_emp', 'debt_to_income_ratio')
# Out:
# C:\Users\aznan\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# length of emp vs approval

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.barplot(data = lc_eo2012, x = 'length_of_emp', y = 'status', ci = 99)

# %% [markdown]
# geo division vs approval

# %%
sns.set(rc={'figure.figsize':(15, 5)})
sns.barplot(data = lc_eo2012, x = 'division', y = 'status', ci = 99)

# %% [markdown]
# geo region vs approval

# %%
sns.set(rc={'figure.figsize':(10, 5)})
sns.barplot(data = lc_eo2012, x = 'region', y = 'status', ci = 99)

# %% [markdown]
# credit score by length of emp

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.barplot(data = lc_eo2012, x = 'length_of_emp', y = 'risk_score', ci = 99)

# %% [markdown]
# number of requests by length of emp

# %%
lc_eo2012.groupby('length_of_emp')[['title']].count().reset_index().sort_values('title', ascending = False)
# Out:
#    length_of_emp   title
# 10      < 1 year  583269
# 1      10+ years   63085
# 2        2 years   35761
# 0         1 year   32687
# 3        3 years   28652
# 4        4 years   23537
# 5        5 years   22614
# 6        6 years   17274
# 7        7 years   13001
# 8        8 years   11329
# 9        9 years    8968

# %% [markdown]
# NLP: title analysis

# %%
lc_eo2012.loc[lc_eo2012['title'].isnull(), 'title'] = 'titleless'

# %%
# dividing titles into 2 groups by status
lc_0_title = lc_eo2012[lc_eo2012['status'] == 0].title
lc_1_title = lc_eo2012[lc_eo2012['status'] == 1].title

# %%
# NLP: selecting text for analysis
title_list_0 = []
for r in lc_0_title.index:
    title_list_0.append(lc_0_title[r])
    
title_list_1 = []
for r in lc_1_title.index:
    title_list_1.append(lc_1_title[r])

# %%
# form the corpus
title_list_0 = ' '.join(title_list_0)
title_list_1 = ' '.join(title_list_1)

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords

# %%
# NLP: removing stop words + tokenization + stemming/lemmatization
def texts_clean(texts):
    """
    A function to clean up the data. All the words that are not designated as a stop word is then lemmatized after
    encoding and basic regex parsing are performed.
    """
    lem = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')
    texts = (unicodedata.normalize('NFKD', texts)
            .encode('ascii', 'ignore')
            .decode('utf-8', 'ignore')
            .lower())
    words = re.sub(r'[^\w\s]', '', texts).split()
    return [lem.lemmatize(word) for word in words if word not in stopwords]

# %%
title_list_0 = texts_clean(title_list_0)
title_list_1 = texts_clean(title_list_1)

# %%
# NLP: creating n-grams
print('top 20: rejected')
print((pd.Series(nltk.ngrams(title_list_0, 2)).value_counts())[:20])
print('--'*40)
print('top 20: accepted')
print((pd.Series(nltk.ngrams(title_list_1, 2)).value_counts())[:20])
# Out:
# top 20: rejected
# (debt, consolidation)       256706
# (consolidation, debt)       119056
# (credit, card)               60738
# (home, improvement)          43581
# (small, business)            39149
# (major, purchase)            36379
# (consolidation, credit)      26370
# (card, debt)                 26178
# (consolidation, home)        18297
# (improvement, debt)          18034
# (business, debt)             17321
# (consolidation, small)       16749
# (consolidation, car)         16552
# (car, debt)                  16496
# (purchase, debt)             15362
# (consolidation, major)       15218
# (consolidation, medical)      8442
# (medical, debt)               8397
# (moving, debt)                7801
# (consolidation, moving)       7796
# dtype: int64
# --------------------------------------------------------------------------------
# top 20: accepted
# (debt, consolidation)             19181
# (credit, card)                    11823
# (consolidation, debt)              5512
# (consolidation, loan)              5345
# (loan, debt)                       4221
# (home, improvement)                2737
# (consolidation, credit)            2378
# (personal, loan)                   2377
# (loan, credit)                     1921
# (card, consolidation)              1880
# (card, debt)                       1790
# (card, refinancing)                1502
# (card, payoff)                     1182
# (card, refinance)                  1151
# (loan, consolidation)              1001
# (consolidation, consolidation)      993
# (business, loan)                    906
# (card, loan)                        903
# (consolidation, home)               868
# (pay, credit)                       863
# dtype: int64

# %%
import collections

# %%
# counting individual words top 20
print('top 20: rejected')
print(collections.Counter(title_list_0).most_common()[:20])
print('--'*40)
print('top 20: accepted')
print(collections.Counter(title_list_1).most_common()[:20])
# Out:
# top 20: rejected
# [('debt', 264849), ('consolidation', 260711), ('credit', 62322), ('card', 61439), ('home', 46388), ('car', 46032), ('business', 43987), ('improvement', 43838), ('small', 39480), ('purchase', 37428), ('major', 36487), ('loan', 25238), ('medical', 20232), ('moving', 18674), ('house', 13684), ('wedding', 13177), ('vacation', 9835), ('personal', 5678), ('pay', 4442), ('need', 4058)]
# --------------------------------------------------------------------------------
# top 20: accepted
# [('debt', 27529), ('consolidation', 26660), ('loan', 20469), ('credit', 13366), ('card', 12822), ('home', 4372), ('personal', 3855), ('pay', 3399), ('payoff', 3257), ('improvement', 3011), ('business', 2319), ('consolidate', 2130), ('refinance', 2114), ('refinancing', 1767), ('wedding', 1661), ('bill', 1540), ('car', 1428), ('cc', 1425), ('purchase', 1172), ('new', 1119)]
